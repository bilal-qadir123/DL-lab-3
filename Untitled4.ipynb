# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("WcWtsi.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
df.index = df.index + 1

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 1              1.2  39344.0
# 2              1.4  46206.0
# 3              1.6  37732.0
# 4              2.1  43526.0
# 5              2.3  39892.0

# %%
X = df[["YearsExperience"]]
y = df["Salary"]

# %%
model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predicted_score_3 = model.predict([[3]])
print("Predicted score for 3 hours of study: ", predicted_score[0])
# Out:
# Predicted score for 3 hours of study:  53198.09093088843
# C:\Users\cs04\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
predicted_score_10 = model.predict([[10]])
print("Predicted score for 3 hours of study: ", predicted_score[0])
# Out:
# Predicted score for 3 hours of study:  53198.09093088843
# C:\Users\cs04\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, color = "green", label = "Actual Data")
plt.plot(X, model.predict(X), color = "blue", label = "Regression line")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Study Hours vs Exam Score")
plt.legend()
plt.show()

# %% [markdown]
# Task 2

# %% [raw]
# df_outlier = pd.read_csv("WcWtsi_Outliers.csv")

# %%
df_outlier = df_outlier.drop(columns=["Unnamed: 0"])

# %%
df_outlier.index = df_outlier.index + 1

# %%
X_outliers = df_outlier[["YearsExperience"]]
y_outliers = df_outlier["Salary"]

# %%
model_outlier = LinearRegression()

# %%
model_outlier.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X_outliers, y_outliers, color = "green", label = "Actual Data")
plt.plot(X_outliers, model_outlier.predict(X_outliers), color = "blue", label = "Regression line")
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.title("Study Hours vs Exam Score")
plt.legend()
plt.show()

# %% [markdown]
# Task 3

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [9449.96232146]
# 24848.203966523208

# %%
y_predicted = model.predict(X)

# %%
mse = mean_squared_error(y, y_predicted)

# %%
print(mse)
# Out:
# 31270951.722280957
